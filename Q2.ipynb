# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z):
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

data = load_boston()                                                              #load dataset
X,Y = data["data"], data["target"]                                                #separate data into input and output features
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           #split data into train and test sets in 80-20 ratio
layer_sizes = [13, 5, 5, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03                                                              #set learning rate for gradient descent
params = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get training and test accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# C:\Users\taham\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)
# Cost at iteration 1 = 293.5256632160988
#
# Cost at iteration 2 = 293.4867010255943
#
# Cost at iteration 3 = 293.447844037516
#
# Cost at iteration 4 = 293.409079837875
#
# Cost at iteration 5 = 293.37039610540853
#
# Cost at iteration 6 = 293.33178625287184
#
# Cost at iteration 7 = 293.29323126309566
#
# Cost at iteration 8 = 293.25472545578697
#
# Cost at iteration 9 = 293.21620235906425
#
# Cost at iteration 10 = 293.1775228877344
#
# Cost at iteration 11 = 293.1385478201749
#
# Cost at iteration 12 = 293.09926725539134
#
# Cost at iteration 13 = 293.05963951727887
#
# Cost at iteration 14 = 293.0197803892808
#
# Cost at iteration 15 = 292.979729301569
#
# Cost at iteration 16 = 292.9394993185929
#
# Cost at iteration 17 = 292.89911819573035
#
# Cost at iteration 18 = 292.8586106934559
#
# Cost at iteration 19 = 292.81796578769695
#
# Cost at iteration 20 = 292.77709801122325
#
# Cost at iteration 21 = 292.7359664265728
#
# Cost at iteration 22 = 292.6947232875537
#
# Cost at iteration 23 = 292.6533871244845
#
# Cost at iteration 24 = 292.6118942275377
#
# Cost at iteration 25 = 292.5702172718915
#
# Cost at iteration 26 = 292.52837306937835
#
# Cost at iteration 27 = 292.4863542106685
#
# Cost at iteration 28 = 292.4442154122797
#
# Cost at iteration 29 = 292.4019880675168
#
# Cost at iteration 30 = 292.3594933244409
#
# Cost at iteration 31 = 292.31665372920673
#
# Cost at iteration 32 = 292.27341181209954
#
# Cost at iteration 33 = 292.22972667489546
#
# Cost at iteration 34 = 292.185531289689
#
# Cost at iteration 35 = 292.1407795387644
#
# Cost at iteration 36 = 292.09543135177614
#
# Cost at iteration 37 = 292.0494263867686
#
# Cost at iteration 38 = 292.00268584402505
#
# Cost at iteration 39 = 291.9551087288396
#
# Cost at iteration 40 = 291.9066028829542
#
# Cost at iteration 41 = 291.85705266878557
#
# Cost at iteration 42 = 291.8063337334749
#
# Cost at iteration 43 = 291.7543304385512
#
# Cost at iteration 44 = 291.7008885469744
#
# Cost at iteration 45 = 291.6458299771579
#
# Cost at iteration 46 = 291.5889583263757
#
# Cost at iteration 47 = 291.53003516048443
#
# Cost at iteration 48 = 291.46877987567245
#
# Cost at iteration 49 = 291.40484426896666
#
# Cost at iteration 50 = 291.33784568229237
#
# Cost at iteration 51 = 291.26729562435173
#
# Cost at iteration 52 = 291.19257157519695
#
# Cost at iteration 53 = 291.1131578157195
#
# Cost at iteration 54 = 291.02838942667216
#
# Cost at iteration 55 = 290.93740378238886
#
# Cost at iteration 56 = 290.83916130911365
#
# Cost at iteration 57 = 290.732404546337
#
# Cost at iteration 58 = 290.61561647490083
#
# Cost at iteration 59 = 290.4869569301378
#
# Cost at iteration 60 = 290.3441576992326
#
# Cost at iteration 61 = 290.18441388349555
#
# Cost at iteration 62 = 290.0042333927555
#
# Cost at iteration 63 = 289.7992347552307
#
# Cost at iteration 64 = 289.5638749089386
#
# Cost at iteration 65 = 289.2910788792552
#
# Cost at iteration 66 = 288.9717303568733
#
# Cost at iteration 67 = 288.59396261893596
#
# Cost at iteration 68 = 288.1421591191388
#
# Cost at iteration 69 = 287.59552608641485
#
# Cost at iteration 70 = 286.9260251447475
#
# Cost at iteration 71 = 286.09533478016556
#
# Cost at iteration 72 = 285.0503159202789
#
# Cost at iteration 73 = 283.7161391760493
#
# Cost at iteration 74 = 281.9857063224053
#
# Cost at iteration 75 = 279.7031322592141
#
# Cost at iteration 76 = 276.6376484224721
#
# Cost at iteration 77 = 272.442126289016
#
# Cost at iteration 78 = 266.5875596617597
#
# Cost at iteration 79 = 258.2628954453534
#
# Cost at iteration 80 = 246.23634931572872
#
# Cost at iteration 81 = 228.7186043193117
#
# Cost at iteration 82 = 203.43790211158344
#
# Cost at iteration 83 = 168.6134573259481
#
# Cost at iteration 84 = 126.18528702467862
#
# Cost at iteration 85 = 86.70965858575843
#
# Cost at iteration 86 = 64.81589749595337
#
# Cost at iteration 87 = 59.261688920447384
#
# Cost at iteration 88 = 58.021041336252495
#
# Cost at iteration 89 = 57.083786035391405
#
# Cost at iteration 90 = 56.18246445609373
#
# Cost at iteration 91 = 55.31097521915239
#
# Cost at iteration 92 = 54.46814680434862
#
# Cost at iteration 93 = 53.65302395428142
#
# Cost at iteration 94 = 52.86479449861269
#
# Cost at iteration 95 = 52.10277083164886
#
# Cost at iteration 96 = 51.36637385296769
#
# Cost at iteration 97 = 50.655118216269
#
# Cost at iteration 98 = 49.96859859925397
#
# Cost at iteration 99 = 49.30647679858885
#
# Cost at iteration 100 = 48.66846950576019
#
# Cost at iteration 101 = 48.05433666345084
#
# Cost at iteration 102 = 47.463870341087194
#
# Cost at iteration 103 = 46.896884103127775
#
# Cost at iteration 104 = 46.353202874673606
#
# Cost at iteration 105 = 45.83265333598704
#
# Cost at iteration 106 = 45.335054900204014
#
# Cost at iteration 107 = 44.860211346479616
#
# Cost at iteration 108 = 44.40790319352694
#
# Cost at iteration 109 = 43.97788090553148
#
# Cost at iteration 110 = 43.56985902338752
#
# Cost at iteration 111 = 43.18351130894031
#
# Cost at iteration 112 = 42.81846697849882
#
# Cost at iteration 113 = 42.47430808468485
#
# Cost at iteration 114 = 42.150568083394994
#
# Cost at iteration 115 = 41.846731596282694
#
# Cost at iteration 116 = 41.56223535000518
#
# Cost at iteration 117 = 41.29647024302843
#
# Cost at iteration 118 = 41.048784460669445
#
# Cost at iteration 119 = 40.81848753092068
#
# Cost at iteration 120 = 40.60485518898796
#
# Cost at iteration 121 = 40.407134898708605
#
# Cost at iteration 122 = 40.22455186511925
#
# Cost at iteration 123 = 40.05631536505266
#
# Cost at iteration 124 = 39.90162522197972
#
# Cost at iteration 125 = 39.75967825718073
#
# Cost at iteration 126 = 39.62967456114429
#
# Cost at iteration 127 = 39.510823445950535
#
# Cost at iteration 128 = 39.40234896015536
#
# Cost at iteration 129 = 39.30349487108059
#
# Cost at iteration 130 = 39.21352904411669
#
# Cost at iteration 131 = 39.13174717340586
#
# Cost at iteration 132 = 39.057475841972845
#
# Cost at iteration 133 = 38.990074911080775
#
# Cost at iteration 134 = 38.928939257607595
#
# Cost at iteration 135 = 38.87349989410508
#
# Cost at iteration 136 = 38.823224518686445
#
# Cost at iteration 137 = 38.77761755097063
#
# Cost at iteration 138 = 38.73621971614732
#
# Cost at iteration 139 = 38.698607242105375
#
# Cost at iteration 140 = 38.664390734873756
#
# Cost at iteration 141 = 38.633213795793
#
# Cost at iteration 142 = 38.60475144032394
#
# Cost at iteration 143 = 38.57870837365025
#
# Cost at iteration 144 = 38.55481717265676
#
# Cost at iteration 145 = 38.532836417828484
#
# Cost at iteration 146 = 38.51254881242545
#
# Cost at iteration 147 = 38.49375932019402
#
# Cost at iteration 148 = 38.47629334706839
#
# Cost at iteration 149 = 38.459994986932266
#
# Cost at iteration 150 = 38.44472534664133
#
# Cost at iteration 151 = 38.430360961199646
#
# Cost at iteration 152 = 38.4167923062547
#
# Cost at iteration 153 = 38.403922411915936
#
# Cost at iteration 154 = 38.39166557928363
#
# Cost at iteration 155 = 38.37994619895522
#
# Cost at iteration 156 = 38.368697669108975
#
# Cost at iteration 157 = 38.357861409493594
#
# Cost at iteration 158 = 38.347385966726634
#
# Cost at iteration 159 = 38.33722862540263
#
# Cost at iteration 160 = 38.327340799374056
#
# Cost at iteration 161 = 38.31688677084028
#
# Cost at iteration 162 = 38.306695927588024
#
# Cost at iteration 163 = 38.29603004425839
#
# Cost at iteration 164 = 38.285517395110496
#
# Cost at iteration 165 = 38.2749309691417
#
# Cost at iteration 166 = 38.26428666398006
#
# Cost at iteration 167 = 38.25386737506192
#
# Cost at iteration 168 = 38.24338828798489
#
# Cost at iteration 169 = 38.23250504333541
#
# Cost at iteration 170 = 38.221843362089835
#
# Cost at iteration 171 = 38.211387599206866
#
# Cost at iteration 172 = 38.201122520719586
#
# Cost at iteration 173 = 38.1910341731204
#
# Cost at iteration 174 = 38.18110975545591
#
# Cost at iteration 175 = 38.1713375162674
#
# Cost at iteration 176 = 38.16170666005226
#
# Cost at iteration 177 = 38.15220726253527
#
# Cost at iteration 178 = 38.142830193909866
#
# Cost at iteration 179 = 38.133567049287684
#
# Cost at iteration 180 = 38.124410592141736
#
# Cost at iteration 181 = 38.1153533546271
#
# Cost at iteration 182 = 38.10638853140213
#
# Cost at iteration 183 = 38.097510044732076
#
# Cost at iteration 184 = 38.08871228053211
#
# Cost at iteration 185 = 38.079990049012245
#
# Cost at iteration 186 = 38.071338549445166
#
# Cost at iteration 187 = 38.062753338116686
#
# Cost at iteration 188 = 38.05423029916049
#
# Cost at iteration 189 = 38.04576561799887
#
# Cost at iteration 190 = 38.037355757139075
#
# Cost at iteration 191 = 38.02897890961421
#
# Cost at iteration 192 = 38.02057137800069
#
# Cost at iteration 193 = 38.012216269691244
#
# Cost at iteration 194 = 38.003910718870685
#
# Cost at iteration 195 = 37.99565193748898
#
# Cost at iteration 196 = 37.987437325943695
#
# Cost at iteration 197 = 37.979264457206895
#
# Cost at iteration 198 = 37.971131064534006
#
# Cost at iteration 199 = 37.963035030076405
#
# Cost at iteration 200 = 37.95497437436901
#
# Cost at iteration 201 = 37.94694724661827
#
# Cost at iteration 202 = 37.93895191572374
#
# Cost at iteration 203 = 37.93098676197271
#
# Cost at iteration 204 = 37.92305026935267
#
# Cost at iteration 205 = 37.91514101843128
#
# Cost at iteration 206 = 37.90725767975834
#
# Cost at iteration 207 = 37.899399007747775
#
# Cost at iteration 208 = 37.89156383500194
#
# Cost at iteration 209 = 37.8837510670433
#
# Cost at iteration 210 = 37.875959677421754
#
# Cost at iteration 211 = 37.86818870316886
#
# Cost at iteration 212 = 37.860437240572175
#
# Cost at iteration 213 = 37.85270444124548
#
# Cost at iteration 214 = 37.84498950847269
#
# Cost at iteration 215 = 37.83729169380499
#
# Cost at iteration 216 = 37.82961029389227
#
# Cost at iteration 217 = 37.82194464753194
#
# Cost at iteration 218 = 37.81429413291897
#
# Cost at iteration 219 = 37.80665816508273
#
# Cost at iteration 220 = 37.79903619349718
#
# Cost at iteration 221 = 37.791427699851944
#
# Cost at iteration 222 = 37.78383219597292
#
# Cost at iteration 223 = 37.776249221881876
#
# Cost at iteration 224 = 37.768678343985215
#
# Cost at iteration 225 = 37.76111915338296
#
# Cost at iteration 226 = 37.753571264289654
#
# Cost at iteration 227 = 37.74603431255936
#
# Cost at iteration 228 = 37.738507954307764
#
# Cost at iteration 229 = 37.73099186462453
#
# Cost at iteration 230 = 37.723485736370066
#
# Cost at iteration 231 = 37.71598927905072
#
# Cost at iteration 232 = 37.7085022177673
#
# Cost at iteration 233 = 37.70102429223193
#
# Cost at iteration 234 = 37.69355525584865
#
# Cost at iteration 235 = 37.686094874853595
#
# Cost at iteration 236 = 37.678642927510744
#
# Cost at iteration 237 = 37.67119920335949
#
# Cost at iteration 238 = 37.66376350251087
#
# Cost at iteration 239 = 37.65633563498886
#
# Cost at iteration 240 = 37.64891542011419
#
# Cost at iteration 241 = 37.64150268592762
#
# Cost at iteration 242 = 37.63409726865017
#
# Cost at iteration 243 = 37.62669901217796
#
# Cost at iteration 244 = 37.61930776760933
#
# Cost at iteration 245 = 37.61192339280226
#
# Cost at iteration 246 = 37.60454575195996
#
# Cost at iteration 247 = 37.59717471524292
#
# Cost at iteration 248 = 37.589810158405754
#
# Cost at iteration 249 = 37.58245196245713
#
# Cost at iteration 250 = 37.57510001334136
#
# Cost at iteration 251 = 37.56775420164026
#
# Cost at iteration 252 = 37.560414422293974
#
# Cost at iteration 253 = 37.55308057433951
#
# Cost at iteration 254 = 37.54575256066592
#
# Cost at iteration 255 = 37.538430287785026
#
# Cost at iteration 256 = 37.531113665616694
#
# Cost at iteration 257 = 37.523802607287685
#
# Cost at iteration 258 = 37.5164970289433
#
# Cost at iteration 259 = 37.509196849571005
#
# Cost at iteration 260 = 37.50190199083514
#
# Cost at iteration 261 = 37.49461237692217
#
# Cost at iteration 262 = 37.4873279343957
#
# Cost at iteration 263 = 37.480048592060676
#
# Cost at iteration 264 = 37.47274729243102
#
# Cost at iteration 265 = 37.46544766002254
#
# Cost at iteration 266 = 37.45815250879686
#
# Cost at iteration 267 = 37.45086179353186
#
# Cost at iteration 268 = 37.443575466980725
#
# Cost at iteration 269 = 37.43629348260591
#
# Cost at iteration 270 = 37.42901579444756
#
# Cost at iteration 271 = 37.421742357105934
#
# Cost at iteration 272 = 37.41447312572068
#
# Cost at iteration 273 = 37.4072080559517
#
# Cost at iteration 274 = 37.39994710396096
#
# Cost at iteration 275 = 37.39269022639568
#
# Cost at iteration 276 = 37.385437380372316
#
# Cost at iteration 277 = 37.37818852346172
#
# Cost at iteration 278 = 37.37094361367511
#
# Cost at iteration 279 = 37.36370260945089
#
# Cost at iteration 280 = 37.3564654696423
#
# Cost at iteration 281 = 37.34923215350587
#
# Cost at iteration 282 = 37.342002620690394
#
# Cost at iteration 283 = 37.334776831226776
#
# Cost at iteration 284 = 37.32755474551838
#
# Cost at iteration 285 = 37.32033632433191
#
# Cost at iteration 286 = 37.313121528788955
#
# Cost at iteration 287 = 37.30591032035791
#
# Cost at iteration 288 = 37.298702660846466
#
# Cost at iteration 289 = 37.29149851239448
#
# Cost at iteration 290 = 37.28429783746732
#
# Cost at iteration 291 = 37.27710059884949
#
# Cost at iteration 292 = 37.26990675963875
#
# Cost at iteration 293 = 37.262716283240486
#
# Cost at iteration 294 = 37.255529133362444
#
# Cost at iteration 295 = 37.24834527400971
#
# Cost at iteration 296 = 37.24116466948004
#
# Cost at iteration 297 = 37.233987284359436
#
# Cost at iteration 298 = 37.22681308351787
#
# Cost at iteration 299 = 37.2196420321054
#
# Cost at iteration 300 = 37.2124740955484
#
# Cost at iteration 301 = 37.205309239546
#
# Cost at iteration 302 = 37.19814743006672
#
# Cost at iteration 303 = 37.19098863334533
#
# Cost at iteration 304 = 37.183832815879825
#
# Cost at iteration 305 = 37.17667994442857
#
# Cost at iteration 306 = 37.16952998600759
#
# Cost at iteration 307 = 37.16238290788802
#
# Cost at iteration 308 = 37.155238677593694
#
# Cost at iteration 309 = 37.14809726289876
#
# Cost at iteration 310 = 37.140958631825576
#
# Cost at iteration 311 = 37.133822752642544
#
# Cost at iteration 312 = 37.126689593862196
#
# Cost at iteration 313 = 37.11955912423925
#
# Cost at iteration 314 = 37.11243131276885
#
# Cost at iteration 315 = 37.1053061286848
#
# Cost at iteration 316 = 37.09818354145802
#
# Cost at iteration 317 = 37.091063520794876
#
# Cost at iteration 318 = 37.08394603663581
#
# Cost at iteration 319 = 37.07683105915383
#
# Cost at iteration 320 = 37.069718656833054
#
# Cost at iteration 321 = 37.06260871501531
#
# Cost at iteration 322 = 37.05550119273981
#
# Cost at iteration 323 = 37.048396061038304
#
# Cost at iteration 324 = 37.041293291191906
#
# Cost at iteration 325 = 37.03419285470846
#
# Cost at iteration 326 = 37.02709472332252
#
# Cost at iteration 327 = 37.01999886899423
#
# Cost at iteration 328 = 37.01290526390812
#
# Cost at iteration 329 = 37.00581388047208
#
# Cost at iteration 330 = 36.99872469131636
#
# Cost at iteration 331 = 36.99163766929253
#
# Cost at iteration 332 = 36.98455278747263
#
# Cost at iteration 333 = 36.977470019148214
#
# Cost at iteration 334 = 36.97038933782952
#
# Cost at iteration 335 = 36.96331071724469
#
# Cost at iteration 336 = 36.956234131338874
#
# Cost at iteration 337 = 36.94915955427357
#
# Cost at iteration 338 = 36.942086960425875
#
# Cost at iteration 339 = 36.9350163243878
#
# Cost at iteration 340 = 36.927947620965554
#
# Cost at iteration 341 = 36.92088082517895
#
# Cost at iteration 342 = 36.91381591226076
#
# Cost at iteration 343 = 36.906752857656144
#
# Cost at iteration 344 = 36.89969163702206
#
# Cost at iteration 345 = 36.8926322262267
#
# Cost at iteration 346 = 36.885574601349006
#
# Cost at iteration 347 = 36.87851873867811
#
# Cost at iteration 348 = 36.87146461471287
#
# Cost at iteration 349 = 36.86441220616139
#
# Cost at iteration 350 = 36.857361489940565
#
# Cost at iteration 351 = 36.850312443175646
#
# Cost at iteration 352 = 36.843265043199786
#
# Cost at iteration 353 = 36.836219267553695
#
# Cost at iteration 354 = 36.829175093985135
#
# Cost at iteration 355 = 36.822132500448696
#
# Cost at iteration 356 = 36.815091465105276
#
# Cost at iteration 357 = 36.808051966321806
#
# Cost at iteration 358 = 36.801013982670916
#
# Cost at iteration 359 = 36.79397749293055
#
# Cost at iteration 360 = 36.7869424760837
#
# Cost at iteration 361 = 36.77990891131807
#
# Cost at iteration 362 = 36.77287677802579
#
# Cost at iteration 363 = 36.765846055803124
#
# Cost at iteration 364 = 36.75881672445018
#
# Cost at iteration 365 = 36.75178876397068
#
# Cost at iteration 366 = 36.74476215457168
#
# Cost at iteration 367 = 36.7377368766633
#
# Cost at iteration 368 = 36.7307129108585
#
# Cost at iteration 369 = 36.723690237972875
#
# Cost at iteration 370 = 36.716668839024386
#
# Cost at iteration 371 = 36.709648695233184
#
# Cost at iteration 372 = 36.70261942115455
#
# Cost at iteration 373 = 36.69555962502723
#
# Cost at iteration 374 = 36.688500512137644
#
# Cost at iteration 375 = 36.681442166840846
#
# Cost at iteration 376 = 36.67438458523307
#
# Cost at iteration 377 = 36.66732776963483
#
# Cost at iteration 378 = 36.66027172044694
#
# Cost at iteration 379 = 36.653216436982945
#
# Cost at iteration 380 = 36.646152571935026
#
# Cost at iteration 381 = 36.63904940487418
#
# Cost at iteration 382 = 36.63194655756073
#
# Cost at iteration 383 = 36.62484410386348
#
# Cost at iteration 384 = 36.61774204676487
#
# Cost at iteration 385 = 36.61064039386231
#
# Cost at iteration 386 = 36.603539150526885
#
# Cost at iteration 387 = 36.59643832069198
#
# Cost at iteration 388 = 36.58933790691821
#
# Cost at iteration 389 = 36.58223791051613
#
# Cost at iteration 390 = 36.57513833165405
#
# Cost at iteration 391 = 36.56803916945859
#
# Cost at iteration 392 = 36.56094042210753
#
# Cost at iteration 393 = 36.55384208691608
#
# Cost at iteration 394 = 36.546744160416594
#
# Cost at iteration 395 = 36.53964663843249
#
# Cost at iteration 396 = 36.53254951614665
#
# Cost at iteration 397 = 36.52545278816477
#
# Cost at iteration 398 = 36.518356448573954
#
# Cost at iteration 399 = 36.511260490997074
#
# Cost at iteration 400 = 36.50416490864294
#
# Cost at iteration 401 = 36.49706969435285
#
# Cost at iteration 402 = 36.489974840643576
#
# Cost at iteration 403 = 36.48288042226614
#
# Cost at iteration 404 = 36.47578638626999
#
# Cost at iteration 405 = 36.468692687559376
#
# Cost at iteration 406 = 36.46159931759012
#
# Cost at iteration 407 = 36.45450626777061
#
# Cost at iteration 408 = 36.447413529374984
#
# Cost at iteration 409 = 36.44032109358017
#
# Cost at iteration 410 = 36.433228951487344
#
# Cost at iteration 411 = 36.42613712655574
#
# Cost at iteration 412 = 36.41904568814528
#
# Cost at iteration 413 = 36.41195451755494
#
# Cost at iteration 414 = 36.404863605424175
#
# Cost at iteration 415 = 36.39777294275721
#
# Cost at iteration 416 = 36.3906825205521
#
# Cost at iteration 417 = 36.38359232985723
#
# Cost at iteration 418 = 36.37650236177835
#
# Cost at iteration 419 = 36.36941260749015
#
# Cost at iteration 420 = 36.36232305824647
#
# Cost at iteration 421 = 36.3552337053897
#
# Cost at iteration 422 = 36.34814454035953
#
# Cost at iteration 423 = 36.34105555470102
#
# Cost at iteration 424 = 36.33396674007201
#
# Cost at iteration 425 = 36.32687808824997
#
# Cost at iteration 426 = 36.31978959113842
#
# Cost at iteration 427 = 36.312701240772725
#
# Cost at iteration 428 = 36.30561302932554
#
# Cost at iteration 429 = 36.298524949111766
#
# Cost at iteration 430 = 36.29143699259319
#
# Cost at iteration 431 = 36.28434915238269
#
# Cost at iteration 432 = 36.277261421248205
#
# Cost at iteration 433 = 36.27017379211632
#
# Cost at iteration 434 = 36.263086258075596
#
# Cost at iteration 435 = 36.25599881237966
#
# Cost at iteration 436 = 36.24891144844999
#
# Cost at iteration 437 = 36.24182415987858
#
# Cost at iteration 438 = 36.23473694043032
#
# Cost at iteration 439 = 36.22764978404514
#
# Cost at iteration 440 = 36.22056268484015
#
# Cost at iteration 441 = 36.21347563711141
#
# Cost at iteration 442 = 36.20638863533569
#
# Cost at iteration 443 = 36.19930167417204
#
# Cost at iteration 444 = 36.192214748463215
#
# Cost at iteration 445 = 36.185127853237006
#
# Cost at iteration 446 = 36.178040983707454
#
# Cost at iteration 447 = 36.170954135275935
#
# Cost at iteration 448 = 36.163867303532186
#
# Cost at iteration 449 = 36.156780484255215
#
# Cost at iteration 450 = 36.14969367341415
#
# Cost at iteration 451 = 36.142606867168965
#
# Cost at iteration 452 = 36.13552006187118
#
# Cost at iteration 453 = 36.12843325406451
#
# Cost at iteration 454 = 36.12134644048536
#
# Cost at iteration 455 = 36.11425961806335
#
# Cost at iteration 456 = 36.10717278392179
#
# Cost at iteration 457 = 36.100085935378004
#
# Cost at iteration 458 = 36.09299906994372
#
# Cost at iteration 459 = 36.08591218532537
#
# Cost at iteration 460 = 36.0788252794243
#
# Cost at iteration 461 = 36.07173835033706
#
# Cost at iteration 462 = 36.064651396355494
#
# Cost at iteration 463 = 36.057564415966965
#
# Cost at iteration 464 = 36.05047740785444
#
# Cost at iteration 465 = 36.04339037089653
#
# Cost at iteration 466 = 36.03625839145828
#
# Cost at iteration 467 = 36.0291202663102
#
# Cost at iteration 468 = 36.02198174311389
#
# Cost at iteration 469 = 36.01484283352817
#
# Cost at iteration 470 = 36.00770355065612
#
# Cost at iteration 471 = 36.00056390628263
#
# Cost at iteration 472 = 35.99342391142143
#
# Cost at iteration 473 = 35.98628357632801
#
# Cost at iteration 474 = 35.97914291058966
#
# Cost at iteration 475 = 35.972001923195464
#
# Cost at iteration 476 = 35.96486062260277
#
# Cost at iteration 477 = 35.95771901679767
#
# Cost at iteration 478 = 35.9505771133507
#
# Cost at iteration 479 = 35.94343491946782
#
# Cost at iteration 480 = 35.93622873089699
#
# Cost at iteration 481 = 35.92901960100395
#
# Cost at iteration 482 = 35.92180986394618
#
# Cost at iteration 483 = 35.91459952577273
#
# Cost at iteration 484 = 35.90738860081849
#
# Cost at iteration 485 = 35.900177101034494
#
# Cost at iteration 486 = 35.89296503793096
#
# Cost at iteration 487 = 35.88575242233234
#
# Cost at iteration 488 = 35.87853926450497
#
# Cost at iteration 489 = 35.87132557421247
#
# Cost at iteration 490 = 35.86411136077731
#
# Cost at iteration 491 = 35.85689663313524
#
# Cost at iteration 492 = 35.84968139988547
#
# Cost at iteration 493 = 35.84246566933644
#
# Cost at iteration 494 = 35.83524944954787
#
# Cost at iteration 495 = 35.828032748368926
#
# Cost at iteration 496 = 35.820815573473354
#
# Cost at iteration 497 = 35.813597945655125
#
# Cost at iteration 498 = 35.80637998367629
#
# Cost at iteration 499 = 35.79916157071913
#
# Cost at iteration 500 = 35.79194271386276
#
# Cost at iteration 501 = 35.784723420350716
#
# Cost at iteration 502 = 35.77750369736807
#
# Cost at iteration 503 = 35.7702836551184
#
# Cost at iteration 504 = 35.76306327314368
#
# Cost at iteration 505 = 35.75584248384281
#
# Cost at iteration 506 = 35.74862129439435
#
# Cost at iteration 507 = 35.7413997121302
#
# Cost at iteration 508 = 35.73417774443381
#
# Cost at iteration 509 = 35.726955398772496
#
# Cost at iteration 510 = 35.71973268270238
#
# Cost at iteration 511 = 35.712509603877514
#
# Cost at iteration 512 = 35.705286170057306
#
# Cost at iteration 513 = 35.69806238911335
#
# Cost at iteration 514 = 35.69083826903558
#
# Cost at iteration 515 = 35.68361381793778
#
# Cost at iteration 516 = 35.67638904406259
#
# Cost at iteration 517 = 35.66916395578589
#
# Cost at iteration 518 = 35.66193856162086
#
# Cost at iteration 519 = 35.65471287022148
#
# Cost at iteration 520 = 35.647486890385686
#
# Cost at iteration 521 = 35.640260631058126
#
# Cost at iteration 522 = 35.633034101332676
#
# Cost at iteration 523 = 35.62580731045455
#
# Cost at iteration 524 = 35.61858026782212
#
# Cost at iteration 525 = 35.611352982988606
#
# Cost at iteration 526 = 35.60412546566335
#
# Cost at iteration 527 = 35.596897725713056
#
# Cost at iteration 528 = 35.589669773162655
#
# Cost at iteration 529 = 35.582441618196114
#
# Cost at iteration 530 = 35.575213271157004
#
# Cost at iteration 531 = 35.567984742548965
#
# Cost at iteration 532 = 35.56075604303596
#
# Cost at iteration 533 = 35.55352718344244
#
# Cost at iteration 534 = 35.54629817475338
#
# Cost at iteration 535 = 35.53906902811421
#
# Cost at iteration 536 = 35.531839754830585
#
# Cost at iteration 537 = 35.52461036636812
#
# Cost at iteration 538 = 35.51738087435203
#
# Cost at iteration 539 = 35.51015129056661
#
# Cost at iteration 540 = 35.50292162695475
#
# Cost at iteration 541 = 35.495691895617256
#
# Cost at iteration 542 = 35.48846210881221
#
# Cost at iteration 543 = 35.48123227895418
#
# Cost at iteration 544 = 35.47400241861342
#
# Cost at iteration 545 = 35.466772540515
#
# Cost at iteration 546 = 35.45954265753786
#
# Cost at iteration 547 = 35.45231278271383
#
# Cost at iteration 548 = 35.44508292922665
#
# Cost at iteration 549 = 35.43785311041081
#
# Cost at iteration 550 = 35.430623339750504
#
# Cost at iteration 551 = 35.423393630878465
#
# Cost at iteration 552 = 35.41616399757471
#
# Cost at iteration 553 = 35.40893445376534
#
# Cost at iteration 554 = 35.4017050135213
#
# Cost at iteration 555 = 35.39447569105701
#
# Cost at iteration 556 = 35.38724650072904
#
# Cost at iteration 557 = 35.38001745703476
#
# Cost at iteration 558 = 35.37278857461091
#
# Cost at iteration 559 = 35.36555986823214
#
# Cost at iteration 560 = 35.35833135280961
#
# Cost at iteration 561 = 35.35110304338941
#
# Cost at iteration 562 = 35.343874955151115
#
# Cost at iteration 563 = 35.336647103406186
#
# Cost at iteration 564 = 35.329419503596384
#
# Cost at iteration 565 = 35.322192171292215
#
# Cost at iteration 566 = 35.31496512219123
#
# Cost at iteration 567 = 35.30773837211646
#
# Cost at iteration 568 = 35.30051193701465
#
# Cost at iteration 569 = 35.293285832954595
#
# Cost at iteration 570 = 35.28600936172593
#
# Cost at iteration 571 = 35.278718041467016
#
# Cost at iteration 572 = 35.27142684208143
#
# Cost at iteration 573 = 35.26413577958164
#
# Cost at iteration 574 = 35.25684487013458
#
# Cost at iteration 575 = 35.249554130051706
#
# Cost at iteration 576 = 35.2422635757849
#
# Cost at iteration 577 = 35.23497322392133
#
# Cost at iteration 578 = 35.227683091179216
#
# Cost at iteration 579 = 35.22039319440377
#
# Cost at iteration 580 = 35.21310355056347
#
# Cost at iteration 581 = 35.2058141767465
#
# Cost at iteration 582 = 35.19852509015751
#
# Cost at iteration 583 = 35.1912363081144
#
# Cost at iteration 584 = 35.18394784804535
#
# Cost at iteration 585 = 35.176659727485884
#
# Cost at iteration 586 = 35.16937196407607
#
# Cost at iteration 587 = 35.16208457555784
#
# Cost at iteration 588 = 35.1547975797722
#
# Cost at iteration 589 = 35.147510994656784
#
# Cost at iteration 590 = 35.14022483824317
#
# Cost at iteration 591 = 35.13293912865437
#
# Cost at iteration 592 = 35.12565388410235
#
# Cost at iteration 593 = 35.11836912288555
#
# Cost at iteration 594 = 35.11108501878524
#
# Cost at iteration 595 = 35.10380144639628
#
# Cost at iteration 596 = 35.096518412853676
#
# Cost at iteration 597 = 35.08923593677907
#
# Cost at iteration 598 = 35.08195403686808
#
# Cost at iteration 599 = 35.07467273188794
#
# Cost at iteration 600 = 35.06739204067498
#
# Cost at iteration 601 = 35.06011198213238
#
# Cost at iteration 602 = 35.05283257522763
#
# Cost at iteration 603 = 35.04555383899022
#
# Cost at iteration 604 = 35.03827579250915
#
# Cost at iteration 605 = 35.0309984549305
#
# Cost at iteration 606 = 35.023721845455036
#
# Cost at iteration 607 = 35.01644598333575
#
# Cost at iteration 608 = 35.009170887875364
#
# Cost at iteration 609 = 35.001896578423896
#
# Cost at iteration 610 = 34.994623074376214
#
# Cost at iteration 611 = 34.98735039516946
#
# Cost at iteration 612 = 34.980078560280646
#
# Cost at iteration 613 = 34.97280758922408
#
# Cost at iteration 614 = 34.96553750154891
#
# Cost at iteration 615 = 34.95826831683652
#
# Cost at iteration 616 = 34.95100005469804
#
# Cost at iteration 617 = 34.9437327347718
#
# Cost at iteration 618 = 34.93646637672077
#
# Cost at iteration 619 = 34.929201000229945
#
# Cost at iteration 620 = 34.9219366250038
#
# Cost at iteration 621 = 34.91467327076374
#
# Cost at iteration 622 = 34.907410957245425
#
# Cost at iteration 623 = 34.90014970419621
#
# Cost at iteration 624 = 34.892889531372504
#
# Cost at iteration 625 = 34.88563045853719
#
# Cost at iteration 626 = 34.87837250545695
#
# Cost at iteration 627 = 34.871115691899604
#
# Cost at iteration 628 = 34.86386003763153
#
# Cost at iteration 629 = 34.85660556241494
#
# Cost at iteration 630 = 34.849352286005264
#
# Cost at iteration 631 = 34.842100228148446
#
# Cost at iteration 632 = 34.83484940857828
#
# Cost at iteration 633 = 34.82759984701374
#
# Cost at iteration 634 = 34.82035156315627
#
# Cost at iteration 635 = 34.81310457668712
#
# Cost at iteration 636 = 34.805858907264586
#
# Cost at iteration 637 = 34.798614574521395
#
# Cost at iteration 638 = 34.79137159806192
#
# Cost at iteration 639 = 34.78412999745953
#
# Cost at iteration 640 = 34.776889792253826
#
# Cost at iteration 641 = 34.76965100194795
#
# Cost at iteration 642 = 34.76241364600588
#
# Cost at iteration 643 = 34.75517774384969
#
# Cost at iteration 644 = 34.747943314856826
#
# Cost at iteration 645 = 34.740710378357385
#
# Cost at iteration 646 = 34.73347895363141
#
# Cost at iteration 647 = 34.726249059906166
#
# Cost at iteration 648 = 34.71902071635338
#
# Cost at iteration 649 = 34.71179394208656
#
# Cost at iteration 650 = 34.70456875615827
#
# Cost at iteration 651 = 34.697345177557395
#
# Cost at iteration 652 = 34.69012322520642
#
# Cost at iteration 653 = 34.68290291795878
#
# Cost at iteration 654 = 34.67568427459604
#
# Cost at iteration 655 = 34.66846731382531
#
# Cost at iteration 656 = 34.66125205427645
#
# Cost at iteration 657 = 34.654038514499426
#
# Cost at iteration 658 = 34.64682671296161
#
# Cost at iteration 659 = 34.639616668045086
#
# Cost at iteration 660 = 34.632408398043964
#
# Cost at iteration 661 = 34.62520192116175
#
# Cost at iteration 662 = 34.61799725550861
#
# Cost at iteration 663 = 34.610794419098816
#
# Cost at iteration 664 = 34.60359342984799
#
# Cost at iteration 665 = 34.596394305570534
#
# Cost at iteration 666 = 34.589197063977004
#
# Cost at iteration 667 = 34.582001722671436
#
# Cost at iteration 668 = 34.57480829914879
#
# Cost at iteration 669 = 34.56761681079235
#
# Cost at iteration 670 = 34.560427274871095
#
# Cost at iteration 671 = 34.55323970853717
#
# Cost at iteration 672 = 34.546054128823314
#
# Cost at iteration 673 = 34.53887055264029
#
# Cost at iteration 674 = 34.531688996774385
#
# Cost at iteration 675 = 34.52450947788487
#
# Cost at iteration 676 = 34.517332012501484
#
# Cost at iteration 677 = 34.51015661702198
#
# Cost at iteration 678 = 34.502983307709606
#
# Cost at iteration 679 = 34.49581210069068
#
# Cost at iteration 680 = 34.48864301195213
#
# Cost at iteration 681 = 34.48147605733908
#
# Cost at iteration 682 = 34.47431125255243
#
# Cost at iteration 683 = 34.4671486131465
#
# Cost at iteration 684 = 34.45998815452661
#
# Cost at iteration 685 = 34.452829891946756
#
# Cost at iteration 686 = 34.44567384050729
#
# Cost at iteration 687 = 34.4385200151526
#
# Cost at iteration 688 = 34.43136843066879
#
# Cost at iteration 689 = 34.42421910168146
#
# Cost at iteration 690 = 34.41707204265344
#
# Cost at iteration 691 = 34.40992726788254
#
# Cost at iteration 692 = 34.40278479149937
#
# Cost at iteration 693 = 34.395644627465174
#
# Cost at iteration 694 = 34.38850678956963
#
# Cost at iteration 695 = 34.38137129142877
#
# Cost at iteration 696 = 34.37423814648282
#
# Cost at iteration 697 = 34.367107367994144
#
# Cost at iteration 698 = 34.35997896904521
#
# Cost at iteration 699 = 34.352852962536495
#
# Cost at iteration 700 = 34.345729361184524
#
# Cost at iteration 701 = 34.338608177519916
#
# Cost at iteration 702 = 34.33148942388533
#
# Cost at iteration 703 = 34.324373112433655
#
# Cost at iteration 704 = 34.31725925512605
#
# Cost at iteration 705 = 34.31014786373007
#
# Cost at iteration 706 = 34.303038949817875
#
# Cost at iteration 707 = 34.295932524764346
#
# Cost at iteration 708 = 34.28882859974538
#
# Cost at iteration 709 = 34.28172718573606
#
# Cost at iteration 710 = 34.27462829350901
#
# Cost at iteration 711 = 34.267531933632625
#
# Cost at iteration 712 = 34.26043811646949
#
# Cost at iteration 713 = 34.25334685217466
#
# Cost at iteration 714 = 34.24625815069415
#
# Cost at iteration 715 = 34.23917202176331
#
# Cost at iteration 716 = 34.23208847490532
#
# Cost at iteration 717 = 34.225007519429646
#
# Cost at iteration 718 = 34.217929164430636
#
# Cost at iteration 719 = 34.210853418786016
#
# Cost at iteration 720 = 34.203780291155546
#
# Cost at iteration 721 = 34.19670978997961
#
# Cost at iteration 722 = 34.18964192347787
#
# Cost at iteration 723 = 34.182576699648024
#
# Cost at iteration 724 = 34.175514126264495
#
# Cost at iteration 725 = 34.16845421087718
#
# Cost at iteration 726 = 34.161396960810315
#
# Cost at iteration 727 = 34.154342383161236
#
# Cost at iteration 728 = 34.147290484799335
#
# Cost at iteration 729 = 34.14024127236489
#
# Cost at iteration 730 = 34.133194752268054
#
# Cost at iteration 731 = 34.12615093068783
#
# Cost at iteration 732 = 34.11910981357108
#
# Cost at iteration 733 = 34.11207140663157
#
# Cost at iteration 734 = 34.10503571534909
#
# Cost at iteration 735 = 34.09800274496854
#
# Cost at iteration 736 = 34.090972500499106
#
# Cost at iteration 737 = 34.083944986713476
#
# Cost at iteration 738 = 34.076920208147044
#
# Cost at iteration 739 = 34.069898169097215
#
# Cost at iteration 740 = 34.06287887362271
#
# Cost at iteration 741 = 34.05586232554287
#
# Cost at iteration 742 = 34.0488485284371
#
# Cost at iteration 743 = 34.041837485644265
#
# Cost at iteration 744 = 34.034829200262116
#
# Cost at iteration 745 = 34.02782367514686
#
# Cost at iteration 746 = 34.02082091291264
#
# Cost at iteration 747 = 34.01382091593109
#
# Cost at iteration 748 = 34.00682368633103
#
# Cost at iteration 749 = 33.99982922599799
#
# Cost at iteration 750 = 33.992837536574015
#
# Cost at iteration 751 = 33.98584861945729
#
# Cost at iteration 752 = 33.978862475801975
#
# Cost at iteration 753 = 33.97187910651794
#
# Cost at iteration 754 = 33.964898512270636
#
# Cost at iteration 755 = 33.957920693480936
#
# Cost at iteration 756 = 33.950945650325096
#
# Cost at iteration 757 = 33.94397338273464
#
# Cost at iteration 758 = 33.93700389039638
#
# Cost at iteration 759 = 33.93003717275243
#
# Cost at iteration 760 = 33.92307322900022
#
# Cost at iteration 761 = 33.916112058092665
#
# Cost at iteration 762 = 33.909153658738234
#
# Cost at iteration 763 = 33.902198029401134
#
# Cost at iteration 764 = 33.895245168301535
#
# Cost at iteration 765 = 33.88829507341575
#
# Cost at iteration 766 = 33.881347742476585
#
# Cost at iteration 767 = 33.87440317297357
#
# Cost at iteration 768 = 33.86746136215337
#
# Cost at iteration 769 = 33.86052230702013
#
# Cost at iteration 770 = 33.8535860043359
#
# Cost at iteration 771 = 33.84665245062109
#
# Cost at iteration 772 = 33.839721642154935
#
# Cost at iteration 773 = 33.83279357497604
#
# Cost at iteration 774 = 33.825868244882926
#
# Cost at iteration 775 = 33.8189456474346
#
# Cost at iteration 776 = 33.81202577795122
#
# Cost at iteration 777 = 33.80510863151469
#
# Cost at iteration 778 = 33.7981942029694
#
# Cost at iteration 779 = 33.79128248692289
#
# Cost at iteration 780 = 33.78437347774668
#
# Cost at iteration 781 = 33.777467169577
#
# Cost at iteration 782 = 33.77056355631561
#
# Cost at iteration 783 = 33.763662631630645
#
# Cost at iteration 784 = 33.75676438895754
#
# Cost at iteration 785 = 33.74986882149988
#
# Cost at iteration 786 = 33.74297592223037
#
# Cost at iteration 787 = 33.73608568389182
# Cost at iteration 788 = 33.72919809899811
#
# Cost at iteration 789 = 33.72231315983525
#
# Cost at iteration 790 = 33.71543085846242
#
# Cost at iteration 791 = 33.70855118671306
#
# Cost at iteration 792 = 33.701674136196
#
# Cost at iteration 793 = 33.69479969829657
#
# Cost at iteration 794 = 33.68792786417783
#
# Cost at iteration 795 = 33.68105862478169
#
# Cost at iteration 796 = 33.6741919708302
#
# Cost at iteration 797 = 33.66732789282677
#
# Cost at iteration 798 = 33.66046638105742
#
# Cost at iteration 799 = 33.65360742559215
#
# Cost at iteration 800 = 33.64675101628621
#
# Cost at iteration 801 = 33.63989714278144
#
# Cost at iteration 802 = 33.6330457945077
#
# Cost at iteration 803 = 33.626196960684226
#
# Cost at iteration 804 = 33.61935063032106
#
# Cost at iteration 805 = 33.61250679222046
#
# Cost at iteration 806 = 33.605665434978434
#
# Cost at iteration 807 = 33.598826546986174
#
# Cost at iteration 808 = 33.59199011643155
#
# Cost at iteration 809 = 33.585156131300714
#
# Cost at iteration 810 = 33.57832457937954
#
# Cost at iteration 811 = 33.57149544825526
#
# Cost at iteration 812 = 33.564668725318064
#
# Cost at iteration 813 = 33.55784439776262
#
# Cost at iteration 814 = 33.551022452589805
#
# Cost at iteration 815 = 33.544202876608246
#
# Cost at iteration 816 = 33.53738565643606
#
# Cost at iteration 817 = 33.530570778502444
#
# Cost at iteration 818 = 33.523758229049434
#
# Cost at iteration 819 = 33.51694799413358
#
# Cost at iteration 820 = 33.51014005962766
#
# Cost at iteration 821 = 33.503334411222426
#
# Cost at iteration 822 = 33.49653103442834
#
# Cost at iteration 823 = 33.48972991457733
#
# Cost at iteration 824 = 33.48293103682462
#
# Cost at iteration 825 = 33.47613438615041
#
# Cost at iteration 826 = 33.46933994736179
#
# Cost at iteration 827 = 33.46254770509445
#
# Cost at iteration 828 = 33.45575764381457
#
# Cost at iteration 829 = 33.448969747820605
#
# Cost at iteration 830 = 33.44218400124517
#
# Cost at iteration 831 = 33.435400388056834
#
# Cost at iteration 832 = 33.42861889206202
#
# Cost at iteration 833 = 33.421839496906856
#
# Cost at iteration 834 = 33.41506218607905
#
# Cost at iteration 835 = 33.40828694290976
#
# Cost at iteration 836 = 33.40151375057551
#
# Cost at iteration 837 = 33.39474259210002
#
# Cost at iteration 838 = 33.38797345035622
#
# Cost at iteration 839 = 33.38120630806801
#
# Cost at iteration 840 = 33.374441147812284
#
# Cost at iteration 841 = 33.36767795202078
#
# Cost at iteration 842 = 33.36091670298202
#
# Cost at iteration 843 = 33.35415738284322
#
# Cost at iteration 844 = 33.347399973612205
#
# Cost at iteration 845 = 33.34064445715935
#
# Cost at iteration 846 = 33.33389081521952
#
# Cost at iteration 847 = 33.32713902939392
#
# Cost at iteration 848 = 33.320389081152115
#
# Cost at iteration 849 = 33.31364095183389
#
# Cost at iteration 850 = 33.30689462265123
#
# Cost at iteration 851 = 33.30015007469015
#
# Cost at iteration 852 = 33.29340728891278
#
# Cost at iteration 853 = 33.28666624615909
#
# Cost at iteration 854 = 33.279926927149
#
# Cost at iteration 855 = 33.27318931248413
#
# Cost at iteration 856 = 33.266453382649836
#
# Cost at iteration 857 = 33.25971911801706
#
# Cost at iteration 858 = 33.252986498844244
#
# Cost at iteration 859 = 33.24625550527925
#
# Cost at iteration 860 = 33.23952611736123
#
# Cost at iteration 861 = 33.23279831502253
#
# Cost at iteration 862 = 33.226072078090574
#
# Cost at iteration 863 = 33.21934738628975
#
# Cost at iteration 864 = 33.21262421924325
#
# Cost at iteration 865 = 33.20590255647498
#
# Cost at iteration 866 = 33.1991823774114
#
# Cost at iteration 867 = 33.192463661383336
#
# Cost at iteration 868 = 33.18574638762787
#
# Cost at iteration 869 = 33.17903053529019
#
# Cost at iteration 870 = 33.172316083425294
#
# Cost at iteration 871 = 33.16560301099997
#
# Cost at iteration 872 = 33.15889129689447
#
# Cost at iteration 873 = 33.15218091990435
#
# Cost at iteration 874 = 33.14547185874229
#
# Cost at iteration 875 = 33.138764092039786
#
# Cost at iteration 876 = 33.132057598348965
#
# Cost at iteration 877 = 33.12535235614434
#
# Cost at iteration 878 = 33.118648343824496
#
# Cost at iteration 879 = 33.11194553971389
#
# Cost at iteration 880 = 33.10524392206449
#
# Cost at iteration 881 = 33.09854346905751
#
# Cost at iteration 882 = 33.0918441588051
#
# Cost at iteration 883 = 33.085145969352006
#
# Cost at iteration 884 = 33.07844887867724
#
# Cost at iteration 885 = 33.07175286469571
#
# Cost at iteration 886 = 33.06505790525988
#
# Cost at iteration 887 = 33.05836397816132
#
# Cost at iteration 888 = 33.051671061132396
#
# Cost at iteration 889 = 33.0449791318478
#
# Cost at iteration 890 = 33.03828816792613
#
# Cost at iteration 891 = 33.03159814693145
#
# Cost at iteration 892 = 33.024909046374816
#
# Cost at iteration 893 = 33.018220843715824
#
# Cost at iteration 894 = 33.011533516364096
#
# Cost at iteration 895 = 33.00484704168078
#
# Cost at iteration 896 = 32.998161396980024
#
# Cost at iteration 897 = 32.99147655953042
#
# Cost at iteration 898 = 32.984792506556445
#
# Cost at iteration 899 = 32.978109215239925
#
# Cost at iteration 900 = 32.971426662721356
#
# Cost at iteration 901 = 32.96474482610139
#
# Cost at iteration 902 = 32.95806368244211
#
# Cost at iteration 903 = 32.951383208768455
#
# Cost at iteration 904 = 32.94470338206951
#
# Cost at iteration 905 = 32.93802417929985
#
# Cost at iteration 906 = 32.93134557738078
#
# Cost at iteration 907 = 32.92466755320172
#
# Cost at iteration 908 = 32.917990083621326
#
# Cost at iteration 909 = 32.91131314546886
#
# Cost at iteration 910 = 32.904636715545315
#
# Cost at iteration 911 = 32.89796077062468
#
# Cost at iteration 912 = 32.891285287455084
#
# Cost at iteration 913 = 32.884610242759976
#
# Cost at iteration 914 = 32.8779356132393
#
# Cost at iteration 915 = 32.87126137557055
#
# Cost at iteration 916 = 32.86458750640993
#
# Cost at iteration 917 = 32.857913982393434
#
# Cost at iteration 918 = 32.851240780137914
#
# Cost at iteration 919 = 32.84456787624211
#
# Cost at iteration 920 = 32.83789524728769
#
# Cost at iteration 921 = 32.83122286984025
#
# Cost at iteration 922 = 32.82455072045034
#
# Cost at iteration 923 = 32.817878775654385
#
# Cost at iteration 924 = 32.81120701197564
#
# Cost at iteration 925 = 32.80453540592516
#
# Cost at iteration 926 = 32.797863934002656
#
# Cost at iteration 927 = 32.79119257269745
#
# Cost at iteration 928 = 32.78452129848927
#
# Cost at iteration 929 = 32.77785008784916
#
# Cost at iteration 930 = 32.7711789172403
#
# Cost at iteration 931 = 32.76450776311879
#
# Cost at iteration 932 = 32.757836601934464
#
# Cost at iteration 933 = 32.75116541013167
#
# Cost at iteration 934 = 32.744494164150005
#
# Cost at iteration 935 = 32.73782284042505
#
# Cost at iteration 936 = 32.73115141538911
#
# Cost at iteration 937 = 32.72447986547186
#
# Cost at iteration 938 = 32.71780816710106
#
# Cost at iteration 939 = 32.71113629670323
#
# Cost at iteration 940 = 32.704464230704204
#
# Cost at iteration 941 = 32.697791945529815
#
# Cost at iteration 942 = 32.691119417606515
#
# Cost at iteration 943 = 32.68444662336188
#
# Cost at iteration 944 = 32.67777353922522
#
# Cost at iteration 945 = 32.671100141628116
#
# Cost at iteration 946 = 32.66442640700494
#
# Cost at iteration 947 = 32.65775231179333
#
# Cost at iteration 948 = 32.65107783243476
#
# Cost at iteration 949 = 32.644402945374885
#
# Cost at iteration 950 = 32.63772762706412
#
# Cost at iteration 951 = 32.631051853957985
#
# Cost at iteration 952 = 32.62437560251753
#
# Cost at iteration 953 = 32.617698849209766
#
# Cost at iteration 954 = 32.611021570508036
#
# Cost at iteration 955 = 32.60434374289233
#
# Cost at iteration 956 = 32.597665342849695
#
# Cost at iteration 957 = 32.590986346874494
#
# Cost at iteration 958 = 32.5843067314688
#
# Cost at iteration 959 = 32.57762647314258
#
# Cost at iteration 960 = 32.5709455484141
#
# Cost at iteration 961 = 32.56426393381001
#
# Cost at iteration 962 = 32.55758160586585
#
# Cost at iteration 963 = 32.55089854112588
#
# Cost at iteration 964 = 32.544214716143856
#
# Cost at iteration 965 = 32.537530107482446
#
# Cost at iteration 966 = 32.53084469171444
#
# Cost at iteration 967 = 32.5241584454216
#
# Cost at iteration 968 = 32.517471345196455
#
# Cost at iteration 969 = 32.510783367640315
#
# Cost at iteration 970 = 32.504094489366196
#
# Cost at iteration 971 = 32.49740468699513
#
# Cost at iteration 972 = 32.490713937161395
#
# Cost at iteration 973 = 32.484022216505636
#
# Cost at iteration 974 = 32.47732950168432
#
# Cost at iteration 975 = 32.47063576935705
#
# Cost at iteration 976 = 32.46394099620388
#
# Cost at iteration 977 = 32.45724515890179
#
# Cost at iteration 978 = 32.45054823415688
#
# Cost at iteration 979 = 32.4438501986602
#
# Cost at iteration 980 = 32.43715102914849
#
# Cost at iteration 981 = 32.43045070232036
#
# Cost at iteration 982 = 32.42374919495208
#
# Cost at iteration 983 = 32.417046483736975
#
# Cost at iteration 984 = 32.410342545508676
#
# Cost at iteration 985 = 32.40363735692973
#
# Cost at iteration 986 = 32.396930894927266
#
# Cost at iteration 987 = 32.39022313608237
#
# Cost at iteration 988 = 32.38351405749016
#
# Cost at iteration 989 = 32.37680363554923
#
# Cost at iteration 990 = 32.37009184767992
#
# Cost at iteration 991 = 32.36337866989932
#
# Cost at iteration 992 = 32.35666408029789
#
# Cost at iteration 993 = 32.349948054136256
#
# Cost at iteration 994 = 32.34323057098139
#
# Cost at iteration 995 = 32.3365116047271
#
# Cost at iteration 996 = 32.329791138509016
#
# Cost at iteration 997 = 32.32306914438618
#
# Cost at iteration 998 = 32.31634561534745
#
# Cost at iteration 999 = 32.30962052455824
#
# Cost at iteration 1000 = 32.302893897131064
#
# Root Mean Squared Error on Training Data = 8.036935452383686
# Root Mean Squared Error on Test Data = 9.170118837825045
