# %%
import pandas as pd
import matplotlib.pyplot as plt
# ^^^ pyforest auto-imports - don't write above this line
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
file = pd.read_csv("weight-height.csv")

# %%
# file.head(5)

# %%
X = file[['Weight']]
X = np.array(X)
Y = file[['Height']]
Y = np.array(Y)

# %%
# %matplotlib inline
plt.xlabel('Weight [pounds]')
plt.ylabel('Height [cm]')
plt.scatter(X, Y, color='red',marker='*') #

# %%
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# [nan] [nan]
# C:\Users\taham\AppData\Local\Temp\ipykernel_16904\2410194925.py:12: RuntimeWarning: overflow encountered in add
#   D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
# C:\Users\taham\AppData\Local\Temp\ipykernel_16904\2410194925.py:14: RuntimeWarning: invalid value encountered in subtract
#   m = m - L * D_m  # Update m

# %%
# reg = linear_model.LinearRegression()
# reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
# reg.predict(np.array([220.042470]).reshape(1,-1))
# Out:
# array([[72.8614237]])

# %%
# reg.intercept_
# Out:
# array([48.47790261])

# %%
# reg.coef_
# Out:
# array([[0.11081279]])

# %%
# # Gradient Descent Code
# ph = intercept + slope*weight
# residual = height - ph
# sqRes = residual**2

# %%
# def predictedH(intercept, slope, weight):
#     return sum(intercept+ slope*weight)

# %%
# plt.plot(Y,X)
